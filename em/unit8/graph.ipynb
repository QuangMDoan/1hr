# %%
import numpy as np 
from numpy import linspace 
import matplotlib.pyplot as pylot 

r = linspace(0, 1, 1000)
E = np.zeros([1000, 1])
r2 = [r[i]*r[i] for i in range(200, 1000)]

E[200, :] = [(4500/rsq) for rsq in r2]
pylot.plot(r, E)
pylot.show()
