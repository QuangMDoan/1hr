# %%
using DSP
a = [1, 0, -1]
b = [2, 1, -1]
c = conv(a, b)
# Out:
# 5-element Vector{Int64}:
#   2
#   1
#  -3
#  -1
#   1

# %%
u = rand([-1, 1], 50)
c = [1, 0.7, -0.3]
y = conv(u, c)
# Out:
# 52-element Vector{Float64}:
#   1.0
#   1.7000000000000002
#  -0.6000000000000001
#  -2.0
#  -1.4
#   0.6
#   1.9999999999999996
#   1.4
#   1.4
#   1.4
#   ⋮
#   0.0
#  -1.9999999999999998
#   0.6000000000000001
#   0.0
#  -2.0
#  -1.4
#  -1.4
#  -0.4
#   0.30000000000000004

# %%
using Plots 

h = [.9, -.5, .5, -.4, .3, -.3, .2, -.1]

z = conv(h, y)

plot(u, label="original signal", color="black")
plot!(y, label="received signal", color = "green")
plot!(z, label="equalized received signal", color="blue")
